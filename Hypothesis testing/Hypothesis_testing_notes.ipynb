# %% [markdown]
# # **Fra sidste uge:**

# %% [markdown]
# ### **Statistisk inferens og konfidensintervaller**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Konfidensinterval og sigifikans niveau (1):**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Konfidensinterval og sigifikans niveau (2):**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Konfidensinterval og sigifikans niveau (3):**
#
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# ## **The hypothesis test**

# %% [markdown]
# ### **Example**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### **Nul hypothesis**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### **T_obs**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Letbane eksemplet hvor vi udregner Tobs
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### **P værdi**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### **Eksempel**
#
# ![image.png](attachment:image.png)
#
# ##### **Fortolkning:**
#
# ![image-2.png](attachment:image-2.png)

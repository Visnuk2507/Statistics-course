# %% [markdown]
# # **Diskrete fordelinger**

# %% [markdown]
# **Tæthedsfunktionen (pdf / pmf)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Fordelingsfunktionen (cdf)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Plot af dem**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Forventningsværdien og varians**
#
# ![image.png](attachment:image.png)

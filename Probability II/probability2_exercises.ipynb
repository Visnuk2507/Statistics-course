# %% [markdown]
# # 2.9 Continuous random variable

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ### **a) The following Python commands and results are given:**
#
# ![image.png](attachment:image.png)
#
# Specify which distributions are used and explain the resulting probabilities (preferably by a sketch).

# %% [markdown]
# #### **Solution:**

# %% [markdown]
# Der er blevet brugt normalfordeling (normal distribution)
#
# The normal distribution function (or normal cumulated density function cdf). The found probabilities are:
#
# ![image.png](attachment:image.png)
#
# **print(stats.norm.cdf(2)):**
# * I den første print statement, er der ikke blevet givet en mean eller standard deviationen, antager man at det er en standard normalfordeling med mean 0 og sigma 1 N(0,1)  at x = 2
#
#   ![image-3.png](attachment:image-3.png)
#
#
#   ![image-5.png](attachment:image-5.png)
#
# **print(stats.norm.cdf(2, 1, 1)):**
# * calculating the CDF for a normal distribution with mean 𝜇=1 and standard deviation σ = 1 at x = 2.
#
#   ![image-2.png](attachment:image-2.png)
#
#
#   ![image-6.png](attachment:image-6.png)
#
#
#
# **print(stats.norm.cdf(2, 1, 2)):**
#
# * This is calculating the CDF for a normal distribution with mean μ=1 and standard deviation σ=2 at x=2
#
#    ![image-4.png](attachment:image-4.png)
#
#
#    ![image-7.png](attachment:image-7.png)

# %%
# sketch

xseq = np.linspace(-4, 4, 1000)
yseq = stats.norm.pdf(xseq)
plt.plot(xseq, yseq)
xseq_fill = np.linspace(-4, 2, 1000) # fill from -4 to 2
yseq_fill = stats.norm.pdf(xseq_fill) # fill from -4 to 2
plt.fill_between(xseq_fill, yseq_fill, color='pink')
xlim = plt.xlim(-4, 4)
ylim = plt.ylim(0, 0.45)
plt.show()

# %% [markdown]
# ### **b) What is the result of the following command: stats.norm.ppf(stats.norm.cdf(2))?**

# %% [markdown]
# #### **Solution:**

# %%
stats.norm.ppf(stats.norm.cdf(2))

# stats.norm.ppf and stats.norm.cdf are each others inverse so the result is the
#same as the argument: 2
# Out:
# 2.0000000000000004

# %% [markdown]
# This is because the ppf (percent point function) is the inverse of the cdf (cumulative distribution function). The cdf of a standard normal distribution at 2 is approximately 0.9772, and the ppf of a standard normal distribution at 0.9772 is approximately 2.

# %% [markdown]
# ### **c) The following Python commands and results are given:**
#
# ![image.png](attachment:image.png)
#
# State what the numbers represent in the three cases (preferably by a sketch).

# %% [markdown]
# #### **Solution:**
#
#
# It shows the 97.5% percentiles for:
# ![image.png](attachment:image.png)

# %%
xseq = np.linspace(-4, 4, 1000)
yseq = stats.norm.pdf(xseq)

plt.plot(xseq, yseq)

## Add the vertical line at the 0.975 quantile
plt.axvline(stats.norm.ppf(0.975), color='red')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## **2.10 The normal pdf**

# %% [markdown]
# ### **a) Which of the following statements regarding the probability density function of the normal distribution $N(1, 2)^2$ is false?**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Solution:**

# %% [markdown]
# 1. True, the total area under the curve is one, since this is true for all probability distributions, see Definition 2.32
#
# 2. True. The mean value is one, and we have that 12 = 1
#
# 3. False, the standard deviation is two and the variance is four
#
# 4. True, the distribution is symmetric around the mean value
#
# 5. True, the normal density is defined between −∞ and ∞

# %% [markdown]
# Let X be normally distributed with mean 24 and variance 16
#
# ### **b) Calculate the following probabilities:**
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Solution:**
#
# remember that the standard deviation is is only 4, but its the variation thats 16!!

# %%
print(stats.norm.cdf(20, 24, 4))

print(1 - stats.norm.cdf(29.5, 24, 4))

# The probability of a continuous random variable to have the outcome equal
#to a single value is zero, i.e. P(X = 23.8) = 0.
# Out:
# 0.15865525393145707
# 0.08456572235133564

# %% [markdown]
# ---

# %% [markdown]
# ## **2.11 Computer chip control**

# %% [markdown]
# A machine for checking computer chips uses on average 65 milliseconds per
# check with a standard deviation of 4 milliseconds. A newer machine, potentially to be bought, uses on average 54 milliseconds per check with a standard deviation of 3 milliseconds. It can be used that check times can be assumed normally distributed and independent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **a) What is the probability that the time savings per check using the new machine is less than 10 milliseconds is?**

# %% [markdown]
# #### **Solution:**

# %%
print(stats.norm.cdf(x=10,loc=11,scale=5))
# Out:
# 0.42074029056089696

# %% [markdown]
# ### **b) What is the mean (µ) and standard deviation (σ) for the total time use for checking 100 chips on the new machine is?**

# %% [markdown]
# #### **Solution:**

# %%
# Part b) Mean and standard deviation for checking 100 chips
mean_time_per_check = 54
std_time_per_check = 3
n_chips = 100

# Mean and standard deviation for checking 100 chips
mean_total_time = n_chips * mean_time_per_check
std_total_time = np.sqrt(n_chips) * std_time_per_check


print(f"Standard deviation for checking 100 chips: {std_total_time} milliseconds")
# Out:
# Standard deviation for checking 100 chips: 30.0 milliseconds

# %% [markdown]
# ## **2.12 Computer chip control**

# %% [markdown]
# A manufacturer of concrete items knows that the length (L) of his items are reasonably normally distributed with µL = 3000 mm and σL = 3 mm. The requirement for these elements is that the length should be not more than 3007 mm and the length must be at least 2993 mm.
#
# ### **a) The expected error rate in the manufacturing will be?**

# %% [markdown]
# #### **Solution:**

# %%
import scipy.stats as stats

# Given values
mu = 3000  # Mean (μ)
sigma = 3  # Standard deviation (σ)

# Limits
lower_limit = 2993  # Lower bound
upper_limit = 3007  # Upper bound

# Probability of lengths falling within the required range
prob_within_range = stats.norm.cdf(upper_limit, mu, sigma) - stats.norm.cdf(lower_limit, mu, sigma)

# Error rate is 1 - probability of being within the range
error_rate = 1 - prob_within_range

print(f"Expected error rate: {error_rate}")
# Out:
# Expected error rate: 0.01963065725729063

# %% [markdown]
# The concrete items are supported by beams, where the distance between the beams is called Lbeam and can be assumed normal distributed. The concrete items length is still called L.
#
# For the items to be supported correctly, the following requirements for these lengths must be fulfilled: 90 mm < L − Lbeam < 110 mm. It is assumed that the mean of the distance between the beams is µbeam = 2900 mm.
#
# ### **How large may the standard deviation σbeam of the distance between the beams be if you want the requirement fulfilled in 99% of the cases?**

# %% [markdown]
# #### **Solution:**

# %%
# Given values from the problem
z_value = 2.576  # Z-score for 99% confidence interval
upper_bound_diff = 10  # Upper bound difference from the mean of 100 mm
variance_constant = 9  # Known variance component

# Calculate the standard deviation σ_beam based on the formula
sigma_beam = np.sqrt((upper_bound_diff / z_value) ** 2 - variance_constant)

# Output the result
print(f"The calculated standard deviation σ_beam is: {sigma_beam:.2f} mm")
# Out:
# The calculated standard deviation σ_beam is: 2.46 mm

# %% [markdown]
# ---

# %% [markdown]
# ### **2.13 Online statistic video views**

# %% [markdown]
# In 2013, there were 110,000 views of the DTU statistics videos that are available online. Assume first that the occurrence of views through 2014 follows a Poisson process with a 2013 average: λ365days = 110000.

# %% [markdown]
# ### **a) What is the probability that in a randomly chosen half an hour there is no occurrence of views?**

# %% [markdown]
# #### **Solution:**

# %%
import numpy as np

# Given values
lambda_per_year = 110000
days_in_year = 365
hours_in_day = 24
minutes_in_hour = 60

# Part a) No occurrence of views in half an hour
lambda_per_day = lambda_per_year / days_in_year
lambda_per_hour = lambda_per_day / hours_in_day
lambda_half_hour = lambda_per_hour / 2

# Poisson probability for no views in half an hour
P_no_views_half_hour = np.exp(-lambda_half_hour)
print(f"Probability of no views in a randomly chosen half hour: {P_no_views_half_hour}")
# Out:
# Probability of no views in a randomly chosen half hour: 0.0018761399841118896
# Probability of waiting more than 15 minutes for the next view: 0.043314431591698045

# %% [markdown]
# ### **b) There has just been a view, what is the probability that you have to wait more than fifteen minutes for the next view?**

# %% [markdown]
# #### **Solution:**

# %%
# Part b) Probability of waiting more than 15 minutes for the next view
lambda_per_minute = lambda_per_hour / minutes_in_hour
P_wait_more_than_15_min = np.exp(-lambda_per_minute * 15)
print(f"Probability of waiting more than 15 minutes for the next view: {P_wait_more_than_15_min}")

# %% [markdown]
# Her er de vigtigste punkter omkring statistisk signifikans:
#
# ## P-værdi:
# ![image.png](attachment:image.png)
#
# ## Signifikansniveau (𝛼)
# ![image-2.png](attachment:image-2.png)
#
#
# ## Type I og Type II Fejl:
# ![image-3.png](attachment:image-3.png)
